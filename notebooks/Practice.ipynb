# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(np.linspace(0, 1, 50),np.linspace(0, 3, 50))

# %%
from random import seed
from random import random
from matplotlib import pyplot
seed(1)
random_walk = list()
random_walk.append(-1 if random() < 0.5 else 1)
for i in range(1, 1000):
    movement = -1 if random() < 0.5 else 1
    value = random_walk[i-1] + movement
    random_walk.append(value)
pyplot.plot(random_walk)
pyplot.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(np.random.normal(0, 1,(1,10)),np.random.normal(0, 1,(1,10)))

# %%
import numpy as np
import matplotlib.pyplot as plt

random_walk = list()
movement = list()
movement.append(-1 if random() < 0.5 else 1)
for i in range(1,100):
    value = -1 if random() < 0.5 else 1
    print(movement[0])
    final = movement[i-1] + value
    random_walk.append(final)
plt.plot(random_walk)
# Out:
# -1
# -1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-232-97faad5e1312> in <module>()
#       8     value = -1 if random() < 0.5 else 1
#       9     print(movement[0])
# ---> 10     final = movement[i-2] + value
#      11     random_walk.append(final)
#      12 plt.plot(random_walk)
#
# IndexError: list index out of range

# %%
from matplotlib import pyplot
seed(1)
random_walk = list()
random_walk.append(-1 if random() < 0.5 else 1)
for i in range(1, 1000):
    movement = -1 if random() < 0.5 else 1
    value = random_walk[i-1] + movement
    random_walk.append(value)
pyplot.plot(random_walk)
pyplot.show()
